# %% [markdown]
# # Linear Classifiers

# %%
# Importng the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
# Importing the dataset
dataset = pd.read_csv('/home/bravin/Documents/Loan Default Prediction Model/vehicle_loans_cleaned.csv', index_col=0)

dataset.head()
# Out:
#           DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# UNIQUEID
# 420825               50578       58400  89.55         67        22807
# 537409               47145       65550  73.23         67        22807
# 417566               53278       61360  89.63         67        22807
# 624493               57513       66113  88.48         67        22807
# 539055               52378       60300  88.39         67        22807
#
#           MANUFACTURER_ID  CURRENT_PINCODE_ID EMPLOYMENT_TYPE  STATE_ID  \
# UNIQUEID
# 420825                 45                1441        Salaried         6
# 537409                 45                1502   Self employed         6
# 417566                 45                1497   Self employed         6
# 624493                 45                1501   Self employed         6
# 539055                 45                1495   Self employed         6
#
#           EMPLOYEE_CODE_ID  ...  PRIMARY_INSTAL_AMT  SEC_INSTAL_AMT  \
# ...

# %%
# inspect columns

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233154 entries, 420825 to 630213
# Data columns (total 40 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   DISBURSED_AMOUNT                     233154 non-null  int64
#  1   ASSET_COST                           233154 non-null  int64
#  2   LTV                                  233154 non-null  float64
#  3   BRANCH_ID                            233154 non-null  int64
#  4   SUPPLIER_ID                          233154 non-null  int64
#  5   MANUFACTURER_ID                      233154 non-null  int64
#  6   CURRENT_PINCODE_ID                   233154 non-null  int64
#  7   EMPLOYMENT_TYPE                      233154 non-null  object
#  8   STATE_ID                             233154 non-null  int64
#  9   EMPLOYEE_CODE_ID                     233154 non-null  int64
#  10  MOBILENO_AVL_FLAG                    233154 non-null  int64
# ...

# %%
category_cols = ['MANUFACTURER_ID', 'STATE_ID', 'DISBURSAL_MONTH', 'PERFORM_CNS_SCORE_DESCRIPTION', 'EMPLOYMENT_TYPE']
dataset[category_cols].dtypes
# Out:
# MANUFACTURER_ID                   int64
# STATE_ID                          int64
# DISBURSAL_MONTH                   int64
# PERFORM_CNS_SCORE_DESCRIPTION    object
# EMPLOYMENT_TYPE                  object
# dtype: object

# %%
# convert to category

dataset[category_cols] = dataset[category_cols].astype('category')
dataset[category_cols].dtypes
# Out:
# MANUFACTURER_ID                  category
# STATE_ID                         category
# DISBURSAL_MONTH                  category
# PERFORM_CNS_SCORE_DESCRIPTION    category
# EMPLOYMENT_TYPE                  category
# dtype: object

# %%
small_cols = ['STATE_ID', 'LTV', 'PERFORM_CNS_SCORE', 'DISBURSAL_MONTH', 'LOAN_DEFAULT']

loan_df_sml = dataset[small_cols]

# %%
# # change LOAN_DEFAULT to 0 and 1
# loan_df_sml['LOAN_DEFAULT'] = loan_df_sml['LOAN_DEFAULT'].map({0:0, 1:1})

loan_df_sml.head()
# Out:
#          STATE_ID    LTV  PERFORM_CNS_SCORE DISBURSAL_MONTH LOAN_DEFAULT
# UNIQUEID
# 420825          6  89.55                  0               3           NO
# 537409          6  73.23                598               9          YES
# 417566          6  89.63                  0               1           NO
# 624493          6  88.48                305              10          YES
# 539055          6  88.39                  0               9          YES

# %%
# create x and y variables for model

X = loan_df_sml.drop('LOAN_DEFAULT', axis=1)
y = loan_df_sml['LOAN_DEFAULT']

# %%
# split data into train and test sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
# initiate model

logmodel = LogisticRegression()

# fit model

logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression()
